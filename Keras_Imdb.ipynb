# %%
import urllib.request
import os
import tarfile

# %%
url = "http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
filepath = "data/aclImdb_v1.tar.gz"
if not os.path.isfile(filepath):
    result = urllib.request.urlretrieve(url, filepath)
    print("downloaded:", result)
# Out:
# downloaded: ('data/aclImdb_v1.tar.gz', <http.client.HTTPMessage object at 0x7fb598864710>)

# %%
if not os.path.exists("data/aclImdb"):
    tfile = tarfile.open("data/aclImdb_v1.tar.gz", 'r:gz')
    result = tfile.extractall("data/")

# %%
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer

# %%
import re
def rm_tags(text):
    re_tag = re.compile(r'<[^>]+>')
    return re_tag.sub('', text)

# %%
def read_files(filetype):
    path = "data/aclImdb/"
    file_list = []
    positive_path = path + filetype + "/pos/"
    for f in os.listdir(positive_path):
        file_list += [positive_path + f]
    negative_path = path + filetype + "/neg/"
    for f in os.listdir(negative_path):
        file_list += [negative_path + f]
    print('read', filetype, 'files:', len(file_list))
    all_labels = ([1] * 12500 + [0] * 12500)
    all_texts = []
    for fi in file_list:
        with open(fi, encoding = 'utf-8') as file_input:
            all_texts += [rm_tags(" ".join(file_input.readlines()))]
    return all_labels, all_texts

# %%
y_train, train_text = read_files("train")
# Out:
# read train files: 25000

# %%
y_test, test_text = read_files("test")
# Out:
# read test files: 25000

# %%
train_text[0]
# Out:
# '"GI Samurai" sees Sonny Chiba and some other guys get transported back to civil war stricken feudal Japan for no particular reason, and much carnage ensues. It\'s a rather over the top essay of sword vs. machine gun that ultimately yields some interesting results.The plot essentially runs along the rails that you might expect from the title; initial fish-out-the-water antics ("what is this flying metal box?" etc etc), "aren\'t we better off here" discussions and ultimately a huge battle. The latter is proof that the film doesn\'t take itself seriously at all, the carnage taking up most of the second half as samurai army battles Chiba\'s platoon; a face off one would fully expect from the title but it still manages to overwhelm with its inventiveness and extravagance. It\'s certainly one of the most unique battle sequences of its time and doesn\'t drag despite its extended length.Chiba gives a gruff performance as Iba, initially a good leader but someone who finally finds himself questioning his own morals as the situation slowly has an effect on him. This is certainly one of his better vehicles from his terrific CV. By the final act the two worlds have had such an effect on each other you have to wonder if it was a bit of nihilism on the part of the writers, as they seem to be asking "weren\'t we better off back then?\'. But this is maybe reading a bit much into was can generally be described as a hugely entertaining two hours of (almost) non stop action.'

# %%
y_train[0]
# Out:
# 1

# %%
train_text[12501]
# Out:
# "There is an excellent reason Edison went straight to video: it would have landed in theaters with a crumbling thud. The movie lasted entirely too long and was perilously boring. Just a notch above lowbrow (thanks to Freeman and Spacey, who obviously had a spare two weeks before their next films), the bad guys are as laughable and action as near non-existent as Justin Timberlake's acting. I hate to knock the guy, but the sooner he realizes that pop is his forte, the better.The movie isn't all bad...just mostly. I like the fact that LL Cool J was given what appears to be a shot at being leading man. He deserves it. And, unlike his fellow musician and co-star, he can act. Kevin Spacey is almost always enjoyable as well (you can see him gulp several times as he chews the scenery), and Freeman has the ability to elevate this flick to three stars (out of ten...he's not THAT good).When all is said and done, the ultimate error with this movie is that it is a mundane and tiresome piece of pseudo-action poppycock that fails to keep anyone awake. It also fails to make anyone give a good crap about any of the characters. All in all, t's just plain boring. That being said, rent this when you are suffering from insomnia."

# %%
y_train[12501]
# Out:
# 0

# %%
token = Tokenizer(num_words=2000)
token.fit_on_texts(train_text)

# %%
print(token.document_count)
# Out:
# 25000

# %%
print(token.word_index)
# Out:
# {"landscapes'": 33055, 'rosebud': 51062, 'arent': 36158, 'grillo': 72982, "vietnam's": 88899, 'downplays': 41263, 'contorts': 50449, "enemy'": 37658, 'blowjobs': 80593, "manufacturer's": 89560, '4am': 28741, 'artbox': 69402, 'wanking': 43124, 'preliminaries': 49286, 'cortney': 66794, "housewife's": 36732, 'gerlich': 44242, 'zb3': 40468, 'mfer': 84962, 'is\x97not': 84062, "brothers'": 12429, 'noakes': 63403, "'femme": 58092, 'mol': 6228, 'kwan': 33037, "'coz": 46432, 'conferred': 74015, 'educate': 12657, 'recognised': 10508, "lily's": 14136, 'cassell': 36084, 'hoffman': 2851, "'willy": 53325, 'szalinsky': 84919, 'ginelli': 72042, 'hieroglyphic': 82116, "corky's": 69008, 'panama': 14095, 'jefferson': 14967, 'oiled': 21893, 'sep': 44514, 'wrongheaded': 42448, 'joachim': 31200, 'pansies': 78983, 'remo': 32798, 'illustrator': 25901, 'bloodying': 61308, 'watchit': 73015, 'grandiose': 11747, 'fatu': 64565, 'arly': 21353, 'purnell': 80608, 'elven': 70122, 'esthetes': 75297, "highway'": 42161, "israelis'": 75356, "pardu's": 75575, 'society': 922, 'romagna': 43010, 'bombsure': 76465, 'filmhistory': 52052, 'academics': 32636, 'gimmicky': 15314, 'revitalizer': 77971, 'frumpiness': 64001, "location'": 46121, 'selwyn': 80809, 'aviv': 10223, 'baraka': 27174, 'duuum': 64903, 'yakusyo': 53942, 'flexes': 44735, 'render': 9609, 'waldis': 58943, 'symbolist': 70280, 'mcdonalds': 14799, 'gigolo': 12837, 'vajna': 61291, 'solicited': 42096, 'xbox': 31610, 'upstages': 36331, 'antwones': 53777, "'bullshit'": 79286, 'jagger': 7667, 'knuckler': 43021, 'archeologists': 66931, 'stroud': 47075, 'cassiopea': 58415, "rvd's": 55666, 'misery': 4616, 'buyruk': 71358, "selby's": 41642, 'backfired': 36906, 'characterswell': 60431, 'import': 12160, 'wreaked': 31591, 'analyzer': 71519, 'pricking': 66373, 'guessed': 4344, "knieval's": 51415, 'pygmalion': 38116, 'burgomeister': 70987, 'player': 1792, 'freq': 88441, 'walkleys': 70598, 'important': 670, 'farm': 3891, 'unmanned': 39215, 'sexiest': 13616, "rifle's": 76534, "bounder'": 83261, 'latins': 63156, 'probably': 238, 'unemotional': 17863, "bochner's": 78101, 'hickenlooper': 74858, 'thlema': 58300, 'switched': 6656, 'nooo': 24029, 'end\x85even': 77041, 'jumper': 28653, 'ponytail': 35837, 'splendors': 42331, 'distinctiveness': 41565, 'arlon': 61417, 'hindusthan': 87913, "amrohi's": 40928, "ass'house": 52633, 'untapped': 32052, 'barnacles': 86893, 'ferguson': 17820, 'glane': 67764, 'unmissable': 17508, 'lawns': 35609, 'discriminates': 53276, 'blackwood': 13930, 'swanston': 45091, 'parfrey': 87837, 'ghosthouse': 27537, 'wasn’t': 78735, 'promises': 4899, 'cushing': 6371, 'exercisethe': 80763, 'birdcage': 33452, 'screwy': 35364, 'nonsenseful': 73891, 'eyeless': 78653, 'angellic': 74970, "lady'": 23899, 'irreligious': 71252, "spies'": 86298, 'voss': 43103, 'skimping': 53584, 'totake': 89639, 'autographed': 48403, "otto's": 52342, "plump's": 50533, 'sweetness': 10556, 'obedience': 32569, "servant's": 75727, 'rattle': 20606, 'bagginses': 62386, 'bibi': 33514, 'abos': 68948, 'sandal': 26380, 'infection': 21004, "porky's": 19850, 'vices': 26980, 'farts': 21239, 'guility': 73479, 'longinotto': 41886, '161': 46108, 'arranging': 23944, 'lycanthropic': 34298, "dobkin's": 89196, 'forwards': 12918, "imamura's": 26885, 'uff': 73411, 'dobkin': 38738, 'maltreat': 84880, 'prettiest': 28020, 'rival': 2995, 'sexo': 20519, 'kurupt': 27431, 'novel': 663, 'attaching': 23133, 'chatrooms': 89213, 'convicted': 6204, "'jailhouse": 87776, 'punkette': 78051, "dolemite's": 37743, "'intensive": 76811, 'stiggs': 44944, 'destabilise': 49642, 'phoolwati': 72434, 'toting': 16531, '480p': 83909, "clutters'": 45284, 'manage': 1921, 'cornball': 16614, 'harlins': 41130, 'jokiness': 78113, "scheider's": 48586, 'ruggedness': 66708, "grant's": 15154, 'unheeded': 45402, "pesci's": 32215, 'epics': 7424, 'laundering': 32922, 'fastened': 48387, 'cuddling': 31342, 'cheyney': 75352, 'indoctrination': 31134, "'director'": 77256, 'hayseed': 38596, "'z'": 65164, 'cla ...

# %%
x_train_seq = token.texts_to_sequences(train_text)
x_test_seq = token.texts_to_sequences(test_text)

# %%
print(train_text[0])
# Out:
# "GI Samurai" sees Sonny Chiba and some other guys get transported back to civil war stricken feudal Japan for no particular reason, and much carnage ensues. It's a rather over the top essay of sword vs. machine gun that ultimately yields some interesting results.The plot essentially runs along the rails that you might expect from the title; initial fish-out-the-water antics ("what is this flying metal box?" etc etc), "aren't we better off here" discussions and ultimately a huge battle. The latter is proof that the film doesn't take itself seriously at all, the carnage taking up most of the second half as samurai army battles Chiba's platoon; a face off one would fully expect from the title but it still manages to overwhelm with its inventiveness and extravagance. It's certainly one of the most unique battle sequences of its time and doesn't drag despite its extended length.Chiba gives a gruff performance as Iba, initially a good leader but someone who finally finds himself questioning his own morals as the situation slowly has an effect on him. This is certainly one of his better vehicles from his terrific CV. By the final act the two worlds have had such an effect on each other you have to wonder if it was a bit of nihilism on the part of the writers, as they seem to be asking "weren't we better off back then?'. But this is maybe reading a bit much into was can generally be described as a hugely entertaining two hours of (almost) non stop action.

# %%
print(x_train_seq[0])
# Out:
# [1078, 2, 45, 81, 489, 74, 141, 5, 321, 1891, 14, 53, 839, 279, 2, 72, 41, 3, 243, 116, 1, 346, 4, 1902, 1686, 1053, 11, 1112, 45, 217, 1896, 1, 110, 1125, 363, 1, 11, 21, 234, 532, 35, 1, 421, 42, 1, 1087, 47, 6, 10, 1543, 949, 519, 519, 708, 71, 124, 121, 129, 2, 1112, 3, 662, 980, 1, 1563, 6, 11, 1, 18, 148, 189, 406, 609, 29, 28, 1, 652, 52, 87, 4, 1, 329, 316, 13, 1264, 3, 389, 121, 27, 58, 1310, 532, 35, 1, 421, 17, 8, 127, 1024, 5, 15, 90, 2, 41, 430, 27, 4, 1, 87, 950, 980, 840, 4, 90, 54, 2, 148, 462, 90, 1608, 405, 3, 235, 13, 3, 48, 17, 290, 33, 413, 654, 305, 23, 201, 13, 1, 899, 1357, 43, 31, 958, 19, 86, 10, 6, 430, 27, 4, 23, 124, 35, 23, 1299, 30, 1, 473, 507, 1, 103, 24, 65, 137, 31, 958, 19, 253, 81, 21, 24, 5, 590, 44, 8, 12, 3, 223, 4, 19, 1, 169, 4, 1, 923, 13, 32, 302, 5, 25, 1166, 71, 124, 121, 141, 91, 804, 17, 10, 6, 275, 882, 3, 223, 72, 79, 12, 66, 1220, 25, 13, 3, 438, 103, 630, 4, 216, 697, 566, 202]

# %%
x_train = sequence.pad_sequences(x_train_seq, maxlen=100)
x_test = sequence.pad_sequences(x_test_seq, maxlen=100)

# %%
print('before pad_sequences length =', len(x_train_seq[0]))
print(x_train_seq[0])
# Out:
# before pad_sequences length = 218
# [1078, 2, 45, 81, 489, 74, 141, 5, 321, 1891, 14, 53, 839, 279, 2, 72, 41, 3, 243, 116, 1, 346, 4, 1902, 1686, 1053, 11, 1112, 45, 217, 1896, 1, 110, 1125, 363, 1, 11, 21, 234, 532, 35, 1, 421, 42, 1, 1087, 47, 6, 10, 1543, 949, 519, 519, 708, 71, 124, 121, 129, 2, 1112, 3, 662, 980, 1, 1563, 6, 11, 1, 18, 148, 189, 406, 609, 29, 28, 1, 652, 52, 87, 4, 1, 329, 316, 13, 1264, 3, 389, 121, 27, 58, 1310, 532, 35, 1, 421, 17, 8, 127, 1024, 5, 15, 90, 2, 41, 430, 27, 4, 1, 87, 950, 980, 840, 4, 90, 54, 2, 148, 462, 90, 1608, 405, 3, 235, 13, 3, 48, 17, 290, 33, 413, 654, 305, 23, 201, 13, 1, 899, 1357, 43, 31, 958, 19, 86, 10, 6, 430, 27, 4, 23, 124, 35, 23, 1299, 30, 1, 473, 507, 1, 103, 24, 65, 137, 31, 958, 19, 253, 81, 21, 24, 5, 590, 44, 8, 12, 3, 223, 4, 19, 1, 169, 4, 1, 923, 13, 32, 302, 5, 25, 1166, 71, 124, 121, 141, 91, 804, 17, 10, 6, 275, 882, 3, 223, 72, 79, 12, 66, 1220, 25, 13, 3, 438, 103, 630, 4, 216, 697, 566, 202]

# %%
print('after pad_sequences length =', len(x_train[0]))
print(x_train[0])
# Out:
# after pad_sequences length = 100
# [  90 1608  405    3  235   13    3   48   17  290   33  413  654  305
#    23  201   13    1  899 1357   43   31  958   19   86   10    6  430
#    27    4   23  124   35   23 1299   30    1  473  507    1  103   24
#    65  137   31  958   19  253   81   21   24    5  590   44    8   12
#     3  223    4   19    1  169    4    1  923   13   32  302    5   25
#  1166   71  124  121  141   91  804   17   10    6  275  882    3  223
#    72   79   12   66 1220   25   13    3  438  103  630    4  216  697
#   566  202]

# %%
print('before pad_sequences length =', len(x_train_seq[1]))
print(x_train_seq[1])
# Out:
# before pad_sequences length = 166
# [9, 292, 10, 232, 310, 15, 360, 1392, 1, 1001, 108, 9, 88, 627, 36, 89, 14, 244, 98, 2, 1705, 24, 9, 419, 173, 98, 17, 1, 7, 1, 207, 464, 5, 36, 10, 34, 9, 515, 8, 3, 576, 142, 1258, 9, 118, 8, 12, 180, 48, 1862, 1259, 2, 13, 528, 17, 7, 3, 92, 32, 67, 112, 13, 64, 1350, 2, 32, 67, 108, 2, 20, 652, 528, 38, 10, 16, 95, 609, 1, 16, 513, 42, 15, 94, 14, 1, 739, 11, 290, 154, 8, 12, 5, 25, 121, 14, 31, 340, 133, 32, 22, 14, 1, 516, 32, 22, 77, 40, 1, 197, 11, 32, 118, 291, 10, 6, 575, 7, 8, 12, 69, 220, 1, 152, 11, 32, 184, 14, 1, 1147, 2, 1862, 1259, 67, 347, 19, 2, 14, 3, 244, 16, 8, 184, 176, 5, 1, 40, 64, 143, 1989, 19, 2, 121, 1, 264, 9, 198, 10, 27, 3, 787, 160, 9, 419, 8, 11, 72]

# %%
print('after pad_sequences length =', len(x_train[1]))
print(x_train[1])
# Out:
# after pad_sequences length = 100
# [  67  108    2   20  652  528   38   10   16   95  609    1   16  513
#    42   15   94   14    1  739   11  290  154    8   12    5   25  121
#    14   31  340  133   32   22   14    1  516   32   22   77   40    1
#   197   11   32  118  291   10    6  575    7    8   12   69  220    1
#   152   11   32  184   14    1 1147    2 1862 1259   67  347   19    2
#    14    3  244   16    8  184  176    5    1   40   64  143 1989   19
#     2  121    1  264    9  198   10   27    3  787  160    9  419    8
#    11   72]
